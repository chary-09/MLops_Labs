# %%
# !pip install mlflow dagshub scikit-learn pandas matplotlib

# %%
# Step: 4 Configure git Colab
# !git config --global user.name "Chary"
# !git config --global user.email charybhanuprasad07@gmail.com

# %%
# !git config --global --list
# Out:
# user.name=Chary
# user.email=charybhanuprasad07@gmail.com

# %%
# Step 5: Clone the DagsHub Repository
TOKEN = "76973037e69273481510386b31ac0e8d69634c08"
# !git clone https://$TOKEN@dagshub.com/charybhanuprasad07/mlops-shared-repo.git
# %cd mlops-shared-repo
# !ls -la
# Out:
# Cloning into 'mlops-shared-repo'...
# ...
# /content/mlops-shared-repo/mlops-shared-repo/mlops-shared-repo/mlops-shared-repo
# total 12
# drwxr-xr-x 3 root root 4096 Aug  8 04:40 .
# drwxr-xr-x 4 root root 4096 Aug  8 04:40 ..
# drwxr-xr-x 7 root root 4096 Aug  8 04:40 .git

# %%
# Step 6: Creat a sample Dataset and Train a model
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
 iris.data, iris.target, test_size=0.2, random_state=42
)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
pred = model.predict(X_test)
acc = accuracy_score(y_test, pred)
print("Accuracy:", acc)
# Out:
# Accuracy: 1.0

# %%
# Step 7: Configure MLflow with DagsHub
import dagshub
import mlflow
print("Accessing as Chary")
dagshub.init(
 repo_owner="charybhanuprasad07",
 repo_name="mlops-shared-repo",
 mlflow=True
)
# Out:
# Accessing as Chary
# Initialized MLflow to track repo "charybhanuprasad07/mlops-shared-repo"
# Repository charybhanuprasad07/mlops-shared-repo initialized!

# %%
with mlflow.start_run():
    mlflow.log_param("n_estimators", 100)
    mlflow.log_metric("accuracy", acc)
    mlflow.sklearn.log_model(model, "random_forest_model")
    with open("result.txt", "w") as f:
        f.write(f"Accuracy: {acc}")
    mlflow.log_artifact("result.txt")
print("Experiment logged successfully")
# Out:
# 2026/08/08 04:40:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run persistent-cat-867 at: https://dagshub.com/charybhanuprasad07/mlops-shared-repo.mlflow/#/experiments/1/runs/777c22d2981f4718b6eac15f36a3b8ff
# 🧪 View experiment at: https://dagshub.com/charybhanuprasad07/mlops-shared-repo.mlflow/#/experiments/1
# Experiment logged successfully

# %%
# Step: 9 Verify MLflow Run
print(mlflow.get_tracking_uri())
# Out:
# https://dagshub.com/charybhanuprasad07/mlops-shared-repo.mlflow

# %%
import mlflow
import dagshub
dagshub.init(
    repo_owner="charybhanuprasad07",
    repo_name="mlops-shared-repo",
    mlflow=True
)
mlflow.set_experiment("MLOps_Skill_3")
with mlflow.start_run():
 mlflow.log_param("model", "RandomForest(RANDOM_FOREST)")
 mlflow.log_param("n_estimators", 100)
 mlflow.log_metric("accuracy", 0.95)
 mlflow.log_metric("f1_score", 0.94)
 mlflow.sklearn.log_model(model, "model")
# Out:
# Initialized MLflow to track repo "charybhanuprasad07/mlops-shared-repo"
# Repository charybhanuprasad07/mlops-shared-repo initialized!
# 2026/08/08 04:41:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run abundant-rook-982 at: https://dagshub.com/charybhanuprasad07/mlops-shared-repo.mlflow/#/experiments/1/runs/58ad557953a84bd387f2b4a885a3996c
# 🧪 View experiment at: https://dagshub.com/charybhanuprasad07/mlops-shared-repo.mlflow/#/experiments/1

# %%
# Step 10: Save Notebook Output
# !mkdir outputs1
# !cp result.txt outputs1/

# %%
# Step 11: Commit Files to DagsHub Repository
# !git add .
# !git commit -m "Added MLflow experiment and outputs(updated)"
# Out:
# [main (root-commit) b11f5b9] Added MLflow experiment and outputs(updated)
#  2 files changed, 2 insertions(+)
#  create mode 100644 outputs1/result.txt
#  create mode 100644 result.txt

# %%
# Step 12: Push Changes to DagsHub
# !git branch
# Out:
# * main

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (4/4), 339 bytes | 339.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://dagshub.com/charybhanuprasad07/mlops-shared-repo.git
#  * [new branch]      main -> main

# %%
# !git push origin main
# Out:
# Everything up-to-date
